# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 758

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bourail
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | ranong
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 1 | chandpur
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | rawson
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | crystal beach
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | kavieng
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | harper
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | bowen
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | marystown
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | ternate
# Processing Record 27 of Set 1 | micheweni
# Processing Record 28 of Set 1 | marsa matruh
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | barcelos
# Processing Record 31 of Set 1 | takoradi
# Processing Record 32 of Set 1 | tambura
# Processing Record 33 of Set 1 | balykshi
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | odesskoye
# Processing Record 37 of Set 1 | miandrivazo
# Processing Record 38 of Set 1 | rincon
# Processing Record 39 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | labuhan
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | mangochi
# Processing Record 45 of Set 1 | sur
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | xai-xai
# Processing Record 50 of Set 1 | yulara
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | bilibino
# Processing Record 3 of Set 2 | iralaya
# Processing Record 4 of Set 2 | okha
# Processing Record 5 of Set 2 | magdagachi
# Processing Record 6 of Set 2 | sibu
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | bathsheba
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | lincoln
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | shingu
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | tishchenskoye
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | road town
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | kijang
# Processing Record 24 of Set 2 | arrecife
# Processing Record 25 of Set 2 | prachuap khiri khan
# Processing Record 26 of Set 2 | honiara
# Processing Record 27 of Set 2 | hasaki
# Processing Record 28 of Set 2 | pavlodar
# Processing Record 29 of Set 2 | alofi
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 2 | hervey bay
# Processing Record 34 of Set 2 | egvekinot
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | vredendal
# Processing Record 39 of Set 2 | rumonge
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | srednekolymsk
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | port blair
# Processing Record 44 of Set 2 | salalah
# Processing Record 45 of Set 2 | udachnyy
# Processing Record 46 of Set 2 | samarai
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 2 | swan hill
# Processing Record 50 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 3 | luhyny
# Processing Record 2 of Set 3 | imeni poliny osipenko
# Processing Record 3 of Set 3 | nevinnomyssk
# Processing Record 4 of Set 3 | mindelo
# Processing Record 5 of Set 3 | makakilo city
# Processing Record 6 of Set 3 | nanortalik
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | sandorfalva
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | zhigansk
# Processing Record 11 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 3 | san policarpo
# Processing Record 13 of Set 3 | nautla
# Processing Record 14 of Set 3 | miguel hidalgo
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 3 | chinhoyi
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | bogorodskoye
# Processing Record 20 of Set 3 | le port
# Processing Record 21 of Set 3 | vero beach
# Processing Record 22 of Set 3 | lata
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | northam
# Processing Record 25 of Set 3 | jalu
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | leshukonskoye
# Processing Record 29 of Set 3 | conceicao do araguaia
# Processing Record 30 of Set 3 | tashigang
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | kholtoson
# Processing Record 33 of Set 3 | puerto asis
# Processing Record 34 of Set 3 | banda aceh
# Processing Record 35 of Set 3 | tekax
# City not found. Skipping...
# Processing Record 36 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 3 | hamilton
# Processing Record 38 of Set 3 | carnduff
# Processing Record 39 of Set 3 | bilma
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | sao miguel do araguaia
# Processing Record 42 of Set 3 | biak
# Processing Record 43 of Set 3 | puerto leguizamo
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | bubaque
# Processing Record 46 of Set 3 | urumqi
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | booue
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | erenhot
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | ugoofaaru
# Processing Record 3 of Set 4 | datong
# Processing Record 4 of Set 4 | vista hermosa
# Processing Record 5 of Set 4 | bereda
# Processing Record 6 of Set 4 | nome
# Processing Record 7 of Set 4 | ha tinh
# Processing Record 8 of Set 4 | saint-pierre
# Processing Record 9 of Set 4 | koper
# Processing Record 10 of Set 4 | hovd
# Processing Record 11 of Set 4 | prince albert
# Processing Record 12 of Set 4 | solnechnyy
# Processing Record 13 of Set 4 | arona
# Processing Record 14 of Set 4 | batagay
# Processing Record 15 of Set 4 | tanout
# Processing Record 16 of Set 4 | durango
# Processing Record 17 of Set 4 | mount isa
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | avera
# Processing Record 20 of Set 4 | pacific grove
# Processing Record 21 of Set 4 | porto seguro
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | tikamgarh
# Processing Record 24 of Set 4 | ayorou
# Processing Record 25 of Set 4 | port hedland
# Processing Record 26 of Set 4 | mgandu
# Processing Record 27 of Set 4 | ust-ilimsk
# Processing Record 28 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 4 | macau
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | zapotiltic
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | yumen
# Processing Record 34 of Set 4 | kalabo
# Processing Record 35 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | aykino
# Processing Record 38 of Set 4 | dobson
# Processing Record 39 of Set 4 | fairbanks
# Processing Record 40 of Set 4 | chengde
# Processing Record 41 of Set 4 | santa cruz
# Processing Record 42 of Set 4 | kokkola
# Processing Record 43 of Set 4 | turukhansk
# Processing Record 44 of Set 4 | komsomolskiy
# Processing Record 45 of Set 4 | borogontsy
# Processing Record 46 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 4 | tuktoyaktuk
# Processing Record 48 of Set 4 | coquimbo
# Processing Record 49 of Set 4 | kasongo
# Processing Record 50 of Set 4 | hofn
# Processing Record 1 of Set 5 | tacuarembo
# Processing Record 2 of Set 5 | hereford
# Processing Record 3 of Set 5 | konya
# Processing Record 4 of Set 5 | bossangoa
# Processing Record 5 of Set 5 | porto walter
# Processing Record 6 of Set 5 | sao joao da barra
# Processing Record 7 of Set 5 | qandala
# Processing Record 8 of Set 5 | kaliningrad
# Processing Record 9 of Set 5 | concarneau
# Processing Record 10 of Set 5 | lillooet
# Processing Record 11 of Set 5 | kanasin
# Processing Record 12 of Set 5 | touros
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | lingao
# Processing Record 15 of Set 5 | ereymentau
# Processing Record 16 of Set 5 | ha giang
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | arlit
# Processing Record 19 of Set 5 | linhares
# Processing Record 20 of Set 5 | kroya
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | kaeo
# Processing Record 23 of Set 5 | orsha
# Processing Record 24 of Set 5 | souillac
# Processing Record 25 of Set 5 | mayma
# Processing Record 26 of Set 5 | alice springs
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | bethel
# Processing Record 29 of Set 5 | tabou
# Processing Record 30 of Set 5 | zapolyarnyy
# Processing Record 31 of Set 5 | codrington
# Processing Record 32 of Set 5 | wajid
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | nemuro
# Processing Record 35 of Set 5 | huntington
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | husavik
# Processing Record 38 of Set 5 | hithadhoo
# Processing Record 39 of Set 5 | yar-sale
# Processing Record 40 of Set 5 | roebourne
# Processing Record 41 of Set 5 | san patricio
# Processing Record 42 of Set 5 | kaitangata
# Processing Record 43 of Set 5 | luba
# Processing Record 44 of Set 5 | asfi
# Processing Record 45 of Set 5 | cabo san lucas
# Processing Record 46 of Set 5 | viedma
# Processing Record 47 of Set 5 | santa rosalia
# Processing Record 48 of Set 5 | cockburn town
# Processing Record 49 of Set 5 | makasar
# Processing Record 50 of Set 5 | port hardy
# Processing Record 1 of Set 6 | sambava
# Processing Record 2 of Set 6 | nisia floresta
# Processing Record 3 of Set 6 | oleksandrivka
# Processing Record 4 of Set 6 | lexington park
# Processing Record 5 of Set 6 | vila
# Processing Record 6 of Set 6 | mao
# Processing Record 7 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 6 | aksarka
# Processing Record 9 of Set 6 | bataipora
# Processing Record 10 of Set 6 | bardiyah
# Processing Record 11 of Set 6 | taltal
# Processing Record 12 of Set 6 | san lorenzo
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | tiksi
# Processing Record 15 of Set 6 | pevek
# Processing Record 16 of Set 6 | kloulklubed
# Processing Record 17 of Set 6 | esperance
# Processing Record 18 of Set 6 | yenagoa
# Processing Record 19 of Set 6 | sindor
# Processing Record 20 of Set 6 | pangnirtung
# Processing Record 21 of Set 6 | sri aman
# Processing Record 22 of Set 6 | kodiak
# Processing Record 23 of Set 6 | deputatskiy
# Processing Record 24 of Set 6 | kiunga
# Processing Record 25 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 26 of Set 6 | davidson
# Processing Record 27 of Set 6 | lorengau
# Processing Record 28 of Set 6 | narsaq
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 6 | thompson
# Processing Record 32 of Set 6 | te anau
# Processing Record 33 of Set 6 | salta
# Processing Record 34 of Set 6 | ust-omchug
# Processing Record 35 of Set 6 | sturgis
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | bairiki
# Processing Record 38 of Set 6 | urucara
# Processing Record 39 of Set 6 | bengkulu
# Processing Record 40 of Set 6 | waingapu
# Processing Record 41 of Set 6 | shaowu
# Processing Record 42 of Set 6 | shubarshi
# Processing Record 43 of Set 6 | erzin
# Processing Record 44 of Set 6 | khatanga
# Processing Record 45 of Set 6 | soyo
# Processing Record 46 of Set 6 | sterling
# Processing Record 47 of Set 6 | beringovskiy
# Processing Record 48 of Set 6 | evensk
# Processing Record 49 of Set 6 | mizdah
# Processing Record 50 of Set 6 | atuona
# Processing Record 1 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 7 | utila
# City not found. Skipping...
# Processing Record 3 of Set 7 | alyangula
# Processing Record 4 of Set 7 | xanxere
# Processing Record 5 of Set 7 | puerto escondido
# Processing Record 6 of Set 7 | terrace
# Processing Record 7 of Set 7 | tura
# Processing Record 8 of Set 7 | port keats
# Processing Record 9 of Set 7 | antsohihy
# Processing Record 10 of Set 7 | macenta
# Processing Record 11 of Set 7 | suyan
# Processing Record 12 of Set 7 | bad langensalza
# Processing Record 13 of Set 7 | sechura
# Processing Record 14 of Set 7 | ypsonas
# Processing Record 15 of Set 7 | linapacan
# City not found. Skipping...
# Processing Record 16 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 7 | itoman
# Processing Record 18 of Set 7 | guadalupe y calvo
# Processing Record 19 of Set 7 | krasnoborsk
# Processing Record 20 of Set 7 | torbay
# Processing Record 21 of Set 7 | cayenne
# Processing Record 22 of Set 7 | talavera de la reina
# Processing Record 23 of Set 7 | goderich
# Processing Record 24 of Set 7 | mukdahan
# Processing Record 25 of Set 7 | lahaina
# Processing Record 26 of Set 7 | languyan
# Processing Record 27 of Set 7 | maragogi
# Processing Record 28 of Set 7 | lixourion
# Processing Record 29 of Set 7 | taperoa
# Processing Record 30 of Set 7 | padang
# Processing Record 31 of Set 7 | haines junction
# Processing Record 32 of Set 7 | katsuura
# Processing Record 33 of Set 7 | camacha
# Processing Record 34 of Set 7 | killybegs
# Processing Record 35 of Set 7 | olafsvik
# Processing Record 36 of Set 7 | ixtapa
# Processing Record 37 of Set 7 | virginia beach
# Processing Record 38 of Set 7 | maracaju
# Processing Record 39 of Set 7 | kasama
# Processing Record 40 of Set 7 | stephenville
# Processing Record 41 of Set 7 | talnakh
# Processing Record 42 of Set 7 | qasigiannguit
# Processing Record 43 of Set 7 | rocha
# Processing Record 44 of Set 7 | vardo
# Processing Record 45 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 7 | acapulco
# Processing Record 47 of Set 7 | bambous virieux
# Processing Record 48 of Set 7 | ketchikan
# Processing Record 49 of Set 7 | kamenka
# Processing Record 50 of Set 7 | galesong
# Processing Record 1 of Set 8 | williamsport
# Processing Record 2 of Set 8 | nhulunbuy
# Processing Record 3 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 8 | charlestown
# Processing Record 5 of Set 8 | margate
# Processing Record 6 of Set 8 | zhucheng
# Processing Record 7 of Set 8 | venado tuerto
# Processing Record 8 of Set 8 | venado
# Processing Record 9 of Set 8 | aksu
# Processing Record 10 of Set 8 | longkou
# Processing Record 11 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 8 | san cristobal
# Processing Record 13 of Set 8 | praia da vitoria
# Processing Record 14 of Set 8 | suao
# City not found. Skipping...
# Processing Record 15 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | ulaangom
# Processing Record 18 of Set 8 | general roca
# Processing Record 19 of Set 8 | balikpapan
# Processing Record 20 of Set 8 | marawi
# Processing Record 21 of Set 8 | yeppoon
# Processing Record 22 of Set 8 | erice
# Processing Record 23 of Set 8 | poum
# Processing Record 24 of Set 8 | thabazimbi
# Processing Record 25 of Set 8 | iroquois falls
# Processing Record 26 of Set 8 | roma
# Processing Record 27 of Set 8 | zemen
# Processing Record 28 of Set 8 | tessalit
# Processing Record 29 of Set 8 | bac lieu
# Processing Record 30 of Set 8 | sao filipe
# Processing Record 31 of Set 8 | san jeronimo
# Processing Record 32 of Set 8 | coahuayana
# Processing Record 33 of Set 8 | cidreira
# Processing Record 34 of Set 8 | meulaboh
# Processing Record 35 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 8 | mackenzie
# Processing Record 37 of Set 8 | kununurra
# Processing Record 38 of Set 8 | carlos antonio lopez
# Processing Record 39 of Set 8 | henties bay
# Processing Record 40 of Set 8 | ribeira grande
# Processing Record 41 of Set 8 | akyab
# Processing Record 42 of Set 8 | ilhabela
# Processing Record 43 of Set 8 | lokachi
# Processing Record 44 of Set 8 | portree
# Processing Record 45 of Set 8 | narayanpet
# Processing Record 46 of Set 8 | mudhol
# Processing Record 47 of Set 8 | grindavik
# Processing Record 48 of Set 8 | faya
# Processing Record 49 of Set 8 | gombong
# Processing Record 50 of Set 8 | teya
# Processing Record 1 of Set 9 | dingle
# Processing Record 2 of Set 9 | chernyshevskiy
# Processing Record 3 of Set 9 | san jose
# Processing Record 4 of Set 9 | waw
# Processing Record 5 of Set 9 | karjat
# Processing Record 6 of Set 9 | hobyo
# Processing Record 7 of Set 9 | junin
# Processing Record 8 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 9 | abu dhabi
# Processing Record 10 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 9 | hit
# Processing Record 12 of Set 9 | safranbolu
# Processing Record 13 of Set 9 | mareeba
# Processing Record 14 of Set 9 | cervo
# Processing Record 15 of Set 9 | quevedo
# Processing Record 16 of Set 9 | half moon bay
# Processing Record 17 of Set 9 | tual
# Processing Record 18 of Set 9 | new richmond
# Processing Record 19 of Set 9 | nanakuli
# Processing Record 20 of Set 9 | malim
# Processing Record 21 of Set 9 | zhezkazgan
# Processing Record 22 of Set 9 | dergachi
# Processing Record 23 of Set 9 | strezhevoy
# Processing Record 24 of Set 9 | krasnoselkup
# Processing Record 25 of Set 9 | sola
# Processing Record 26 of Set 9 | hirara
# Processing Record 27 of Set 9 | angoche
# Processing Record 28 of Set 9 | camapua
# Processing Record 29 of Set 9 | kahului
# Processing Record 30 of Set 9 | daru
# Processing Record 31 of Set 9 | geraldton
# Processing Record 32 of Set 9 | lasa
# Processing Record 33 of Set 9 | norman wells
# Processing Record 34 of Set 9 | lebu
# Processing Record 35 of Set 9 | amqui
# Processing Record 36 of Set 9 | upig
# Processing Record 37 of Set 9 | khvalynsk
# Processing Record 38 of Set 9 | weligama
# Processing Record 39 of Set 9 | griffith
# Processing Record 40 of Set 9 | beloha
# Processing Record 41 of Set 9 | boyolangu
# Processing Record 42 of Set 9 | tarakan
# Processing Record 43 of Set 9 | lagoa
# Processing Record 44 of Set 9 | pokaran
# Processing Record 45 of Set 9 | buritis
# Processing Record 46 of Set 9 | taoudenni
# Processing Record 47 of Set 9 | soledade
# Processing Record 48 of Set 9 | guarda
# Processing Record 49 of Set 9 | sakakah
# Processing Record 50 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 1 of Set 10 | auki
# Processing Record 2 of Set 10 | otradnoye
# Processing Record 3 of Set 10 | hammerfest
# Processing Record 4 of Set 10 | belmonte
# Processing Record 5 of Set 10 | urengoy
# Processing Record 6 of Set 10 | saint george
# Processing Record 7 of Set 10 | aden
# Processing Record 8 of Set 10 | oiba
# Processing Record 9 of Set 10 | emerald
# Processing Record 10 of Set 10 | kutum
# Processing Record 11 of Set 10 | camana
# Processing Record 12 of Set 10 | mataram
# Processing Record 13 of Set 10 | vila velha
# Processing Record 14 of Set 10 | rafraf
# Processing Record 15 of Set 10 | cap malheureux
# Processing Record 16 of Set 10 | xiangxiang
# Processing Record 17 of Set 10 | ingham
# Processing Record 18 of Set 10 | el alto
# Processing Record 19 of Set 10 | karatsu
# Processing Record 20 of Set 10 | khasan
# Processing Record 21 of Set 10 | kyren
# Processing Record 22 of Set 10 | chingirlau
# Processing Record 23 of Set 10 | ashqelon
# Processing Record 24 of Set 10 | kambam
# Processing Record 25 of Set 10 | kushiro
# Processing Record 26 of Set 10 | uyovu
# Processing Record 27 of Set 10 | kathu
# Processing Record 28 of Set 10 | suwalki
# Processing Record 29 of Set 10 | gorontalo
# Processing Record 30 of Set 10 | catuday
# Processing Record 31 of Set 10 | whitehorse
# Processing Record 32 of Set 10 | gympie
# Processing Record 33 of Set 10 | miranda de ebro
# Processing Record 34 of Set 10 | bhadrak
# Processing Record 35 of Set 10 | anadyr
# Processing Record 36 of Set 10 | kez
# Processing Record 37 of Set 10 | luwuk
# Processing Record 38 of Set 10 | tezu
# Processing Record 39 of Set 10 | rosetta
# Processing Record 40 of Set 10 | great yarmouth
# Processing Record 41 of Set 10 | murgab
# Processing Record 42 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 10 | baker city
# Processing Record 44 of Set 10 | glace bay
# Processing Record 45 of Set 10 | tukrah
# Processing Record 46 of Set 10 | kodinsk
# Processing Record 47 of Set 10 | camalu
# Processing Record 48 of Set 10 | hudson bay
# Processing Record 49 of Set 10 | lamu
# Processing Record 50 of Set 10 | sinegorye
# Processing Record 1 of Set 11 | poya
# Processing Record 2 of Set 11 | fare
# Processing Record 3 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 4 of Set 11 | victor harbor
# Processing Record 5 of Set 11 | batagay-alyta
# Processing Record 6 of Set 11 | nassau
# Processing Record 7 of Set 11 | guerrero negro
# Processing Record 8 of Set 11 | harlingen
# Processing Record 9 of Set 11 | gigmoto
# Processing Record 10 of Set 11 | rawah
# Processing Record 11 of Set 11 | kibaya
# Processing Record 12 of Set 11 | manacapuru
# Processing Record 13 of Set 11 | almaznyy
# Processing Record 14 of Set 11 | olinda
# Processing Record 15 of Set 11 | nouadhibou
# Processing Record 16 of Set 11 | arcata
# Processing Record 17 of Set 11 | luganville
# Processing Record 18 of Set 11 | vanimo
# Processing Record 19 of Set 11 | sergeyevka
# Processing Record 20 of Set 11 | yelizovo
# Processing Record 21 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 22 of Set 11 | turhal
# Processing Record 23 of Set 11 | orlik
# Processing Record 24 of Set 11 | vestmannaeyjar
# Processing Record 25 of Set 11 | aransas pass
# Processing Record 26 of Set 11 | kaka
# Processing Record 27 of Set 11 | tailai
# Processing Record 28 of Set 11 | bud
# Processing Record 29 of Set 11 | durres
# Processing Record 30 of Set 11 | anuchino
# Processing Record 31 of Set 11 | inhambane
# Processing Record 32 of Set 11 | bandarbeyla
# Processing Record 33 of Set 11 | araguaina
# Processing Record 34 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 11 | oyem
# Processing Record 36 of Set 11 | saint anthony
# Processing Record 37 of Set 11 | sisimiut
# Processing Record 38 of Set 11 | pochutla
# Processing Record 39 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 11 | moussoro
# Processing Record 41 of Set 11 | mandera
# Processing Record 42 of Set 11 | porbandar
# Processing Record 43 of Set 11 | namatanai
# Processing Record 44 of Set 11 | pimentel
# Processing Record 45 of Set 11 | sao sebastiao
# Processing Record 46 of Set 11 | quelimane
# Processing Record 47 of Set 11 | hokitika
# Processing Record 48 of Set 11 | oranjemund
# Processing Record 49 of Set 11 | ostrovnoy
# Processing Record 50 of Set 11 | constitucion
# Processing Record 1 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 2 of Set 12 | ahipara
# Processing Record 3 of Set 12 | karachi
# Processing Record 4 of Set 12 | namibe
# Processing Record 5 of Set 12 | cascais
# Processing Record 6 of Set 12 | baoqing
# Processing Record 7 of Set 12 | arman
# Processing Record 8 of Set 12 | arroyo
# Processing Record 9 of Set 12 | mahebourg
# Processing Record 10 of Set 12 | carutapera
# Processing Record 11 of Set 12 | abalak
# Processing Record 12 of Set 12 | skjervoy
# Processing Record 13 of Set 12 | salmas
# Processing Record 14 of Set 12 | methven
# Processing Record 15 of Set 12 | sept-iles
# Processing Record 16 of Set 12 | riyadh
# Processing Record 17 of Set 12 | alexandria
# Processing Record 18 of Set 12 | sorong
# Processing Record 19 of Set 12 | lieksa
# Processing Record 20 of Set 12 | salamanca
# Processing Record 21 of Set 12 | strizhi
# Processing Record 22 of Set 12 | kruisfontein
# Processing Record 23 of Set 12 | anderson
# Processing Record 24 of Set 12 | kajaani
# Processing Record 25 of Set 12 | haapsalu
# Processing Record 26 of Set 12 | sao francisco de paula
# Processing Record 27 of Set 12 | oistins
# Processing Record 28 of Set 12 | savannah bight
# Processing Record 29 of Set 12 | makung
# City not found. Skipping...
# Processing Record 30 of Set 12 | muika
# City not found. Skipping...
# Processing Record 31 of Set 12 | berlevag
# Processing Record 32 of Set 12 | panalingaan
# Processing Record 33 of Set 12 | rantauprapat
# Processing Record 34 of Set 12 | lavrentiya
# Processing Record 35 of Set 12 | teo
# Processing Record 36 of Set 12 | narok
# Processing Record 37 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 12 | melekhovo
# Processing Record 39 of Set 12 | baruun-urt
# Processing Record 40 of Set 12 | mbini
# Processing Record 41 of Set 12 | axim
# Processing Record 42 of Set 12 | korla
# Processing Record 43 of Set 12 | sioux lookout
# Processing Record 44 of Set 12 | rzhaksa
# Processing Record 45 of Set 12 | montepuez
# Processing Record 46 of Set 12 | kattivakkam
# Processing Record 47 of Set 12 | placido de castro
# Processing Record 48 of Set 12 | tadine
# Processing Record 49 of Set 12 | vagur
# Processing Record 50 of Set 12 | alamogordo
# Processing Record 1 of Set 13 | plyussa
# Processing Record 2 of Set 13 | rockland
# Processing Record 3 of Set 13 | praia
# Processing Record 4 of Set 13 | qianguo
# Processing Record 5 of Set 13 | kapuskasing
# Processing Record 6 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 7 of Set 13 | sale
# Processing Record 8 of Set 13 | pontes e lacerda
# Processing Record 9 of Set 13 | mogadishu
# Processing Record 10 of Set 13 | bahia blanca
# Processing Record 11 of Set 13 | dagana
# Processing Record 12 of Set 13 | suntar
# Processing Record 13 of Set 13 | lhuntshi
# City not found. Skipping...
# Processing Record 14 of Set 13 | valle de allende
# Processing Record 15 of Set 13 | xuanhua
# Processing Record 16 of Set 13 | aban
# Processing Record 17 of Set 13 | ballina
# Processing Record 18 of Set 13 | severnyy
# Processing Record 19 of Set 13 | labytnangi
# Processing Record 20 of Set 13 | keti bandar
# Processing Record 21 of Set 13 | bratsk
# Processing Record 22 of Set 13 | tiarei
# Processing Record 23 of Set 13 | manokwari
# Processing Record 24 of Set 13 | mopipi
# Processing Record 25 of Set 13 | jaciara
# Processing Record 26 of Set 13 | mocuba
# Processing Record 27 of Set 13 | dalbandin
# Processing Record 28 of Set 13 | copiapo
# Processing Record 29 of Set 13 | candido mendes
# Processing Record 30 of Set 13 | botwood
# Processing Record 31 of Set 13 | nyurba
# Processing Record 32 of Set 13 | alta floresta
# Processing Record 33 of Set 13 | gamba
# Processing Record 34 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 13 | mirnyy
# Processing Record 37 of Set 13 | richmond
# Processing Record 38 of Set 13 | bambanglipuro
# Processing Record 39 of Set 13 | istisu
# Processing Record 40 of Set 13 | anisoc
# Processing Record 41 of Set 13 | mookane
# Processing Record 42 of Set 13 | windsor
# Processing Record 43 of Set 13 | archidona
# Processing Record 44 of Set 13 | sayyan
# Processing Record 45 of Set 13 | antalaha
# Processing Record 46 of Set 13 | lompoc
# Processing Record 47 of Set 13 | ostersund
# Processing Record 48 of Set 13 | dukat
# Processing Record 49 of Set 13 | miles city
# Processing Record 50 of Set 13 | pangody
# Processing Record 1 of Set 14 | chara
# Processing Record 2 of Set 14 | tahoua
# Processing Record 3 of Set 14 | awjilah
# Processing Record 4 of Set 14 | umm kaddadah
# Processing Record 5 of Set 14 | tambo
# Processing Record 6 of Set 14 | amalapuram
# Processing Record 7 of Set 14 | wanxian
# Processing Record 8 of Set 14 | bronnoysund
# Processing Record 9 of Set 14 | port-cartier
# Processing Record 10 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 14 | hami
# Processing Record 12 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 13 of Set 14 | ilovlya
# Processing Record 14 of Set 14 | moa
# Processing Record 15 of Set 14 | safford
# Processing Record 16 of Set 14 | seoul
# Processing Record 17 of Set 14 | ouadda
# Processing Record 18 of Set 14 | buarcos
# Processing Record 19 of Set 14 | linchuan
# City not found. Skipping...
# Processing Record 20 of Set 14 | sinazongwe
# Processing Record 21 of Set 14 | terekli-mekteb
# Processing Record 22 of Set 14 | powassan
# Processing Record 23 of Set 14 | landeck
# Processing Record 24 of Set 14 | fuling
# Processing Record 25 of Set 14 | eyl
# Processing Record 26 of Set 14 | grand gaube
# Processing Record 27 of Set 14 | roald
# Processing Record 28 of Set 14 | boden
# Processing Record 29 of Set 14 | delmas
# Processing Record 30 of Set 14 | taybad
# Processing Record 31 of Set 14 | uray
# Processing Record 32 of Set 14 | ca mau
# Processing Record 33 of Set 14 | bat yam
# Processing Record 34 of Set 14 | lakes entrance
# Processing Record 35 of Set 14 | were ilu
# Processing Record 36 of Set 14 | chapais
# Processing Record 37 of Set 14 | ayan
# Processing Record 38 of Set 14 | maumere
# Processing Record 39 of Set 14 | raton
# Processing Record 40 of Set 14 | limon
# Processing Record 41 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 43 of Set 14 | ustynivka
# Processing Record 44 of Set 14 | ocampo
# Processing Record 45 of Set 14 | shkotovo-22
# City not found. Skipping...
# Processing Record 46 of Set 14 | asau
# Processing Record 47 of Set 14 | puerto baquerizo moreno
# Processing Record 48 of Set 14 | buraydah
# Processing Record 49 of Set 14 | belyy yar
# Processing Record 50 of Set 14 | san joaquin
# Processing Record 1 of Set 15 | bichura
# Processing Record 2 of Set 15 | boende
# Processing Record 3 of Set 15 | zarichne
# Processing Record 4 of Set 15 | maneadero
# Processing Record 5 of Set 15 | ambilobe
# Processing Record 6 of Set 15 | fort nelson
# Processing Record 7 of Set 15 | porto velho
# Processing Record 8 of Set 15 | jawhar
# Processing Record 9 of Set 15 | lucea
# Processing Record 10 of Set 15 | krasnaya poyma
# Processing Record 11 of Set 15 | slave lake
# Processing Record 12 of Set 15 | wufeng
# Processing Record 13 of Set 15 | mansoa
# Processing Record 14 of Set 15 | wenling
# Processing Record 15 of Set 15 | paraiso
# Processing Record 16 of Set 15 | flinders
# Processing Record 17 of Set 15 | mato verde
# Processing Record 18 of Set 15 | ekibastuz
# Processing Record 19 of Set 15 | hargeysa
# Processing Record 20 of Set 15 | sheopur
# Processing Record 21 of Set 15 | kalmunai
# Processing Record 22 of Set 15 | charters towers
# Processing Record 23 of Set 15 | tautira
# Processing Record 24 of Set 15 | xining
# Processing Record 25 of Set 15 | varzea da palma
# Processing Record 26 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 15 | ishinomaki
# Processing Record 28 of Set 15 | igarka
# Processing Record 29 of Set 15 | baishishan
# Processing Record 30 of Set 15 | mutare
# Processing Record 31 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 15 | ascension
# Processing Record 33 of Set 15 | bozeman
# Processing Record 34 of Set 15 | coromandel
# Processing Record 35 of Set 15 | sao lourenco do sul
# Processing Record 36 of Set 15 | cuxhaven
# Processing Record 37 of Set 15 | nacimiento
# Processing Record 38 of Set 15 | ales
# Processing Record 39 of Set 15 | birjand
# Processing Record 40 of Set 15 | lenki
# City not found. Skipping...
# Processing Record 41 of Set 15 | sabang
# Processing Record 42 of Set 15 | baijiantan
# Processing Record 43 of Set 15 | salinopolis
# Processing Record 44 of Set 15 | champerico
# Processing Record 45 of Set 15 | thinadhoo
# Processing Record 46 of Set 15 | lesogorskiy
# Processing Record 47 of Set 15 | ponta delgada
# Processing Record 48 of Set 15 | pyapon
# Processing Record 49 of Set 15 | prince rupert
# Processing Record 50 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 16 | north bend
# Processing Record 2 of Set 16 | la libertad
# Processing Record 3 of Set 16 | cap-aux-meules
# Processing Record 4 of Set 16 | ganzhou
# Processing Record 5 of Set 16 | campbellton
# Processing Record 6 of Set 16 | boa vista
# Processing Record 7 of Set 16 | liverpool
# Processing Record 8 of Set 16 | nema
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 699

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bourail -21.5667  165.4833     77.43        57          84
# 1       Busselton -33.6500  115.3333     65.70        51          63
# 2           Vaini -21.2000 -175.2000     80.76        89          20
# 3  Severo-Kurilsk  50.6789  156.1250     49.28        88         100
# 4          Ranong   9.9658   98.6348     75.25        99         100
# 5         Ushuaia -54.8000  -68.3000     44.26        61          75
# 6    Punta Arenas -53.1500  -70.9167     46.11        65          11
# 7          Albany  42.6001  -73.9662     44.55        86          35
# 8        Chandpur  29.1500   78.2667     79.81        53           0
# 9         Iqaluit  63.7506  -68.5145     38.70        93          97
#
#    Wind Speed Country Current Description
# 0        6.08      NC       broken clouds
# 1       10.02      AU       broken clouds
# 2        5.75      TO          few clouds
# 3       19.28      RU     overcast clouds
# 4        2.77      TH     overcast clouds
# 5        3.44      AR       broken clouds
# 6        8.14      CL          few clouds
# 7        2.39      US    scattered clouds
# 8        1.61      IN           clear sky
# 9       23.00      CA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp",
                    "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bourail      NC -21.5667  165.4833     77.43        57          84
# 1       Busselton      AU -33.6500  115.3333     65.70        51          63
# 2           Vaini      TO -21.2000 -175.2000     80.76        89          20
# 3  Severo-Kurilsk      RU  50.6789  156.1250     49.28        88         100
# 4          Ranong      TH   9.9658   98.6348     75.25        99         100
# 5         Ushuaia      AR -54.8000  -68.3000     44.26        61          75
# 6    Punta Arenas      CL -53.1500  -70.9167     46.11        65          11
# 7          Albany      US  42.6001  -73.9662     44.55        86          35
# 8        Chandpur      IN  29.1500   78.2667     79.81        53           0
# 9         Iqaluit      CA  63.7506  -68.5145     38.70        93          97
#
#    Wind Speed Current Description
# 0        6.08       broken clouds
# 1       10.02       broken clouds
# 2        5.75          few clouds
# 3       19.28     overcast clouds
# 4        2.77     overcast clouds
# 5        3.44       broken clouds
# 6        8.14          few clouds
# 7        2.39    scattered clouds
# 8        1.61           clear sky
# 9       23.00     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
